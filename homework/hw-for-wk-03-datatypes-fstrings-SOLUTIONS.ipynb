# %% [markdown]
# # Homework for Week 3
#
# The goal for this homework is to see the relevant journalistic uses for what we learned in class in week 1.
#
# 1. Making numbers more readable (using f-string literal formatting)
# 2. Organizing data points after acquiring them through scraping (creating lists, dictionaries and lists of dictionaries)
# 3. Knowing what type of data (or Python object) we have.
# 4. Knowing how many such data points we have.

# %% [markdown]
# ## Working with Numbers

# %% [markdown]
# ### Question 1
#
# Create a variable called that holds Paycheck Protection Plan loans that total $45.3 million
#
# Print a statement that says "Paycheck Protection Plan loans totalled (number provided here) in 2021" using f-string literal (0 decimal places)
#
# To be clear, you **must** use f-string literals and a variable and **NOT** just type out the sentence above.

# %%
### answer question 1 here (create more cells if necessary)
ppp_loans = 45_300_000
print(f"Paycheck Protection Plan loans that totalled ${ppp_loans:,} in 2021.")
# Out:
# Paycheck Protection Plan loans that totalled $45,300,000 in 2021.

# %% [markdown]
# ### Question 2
#
# An executive earned ```$45,000 in 1973```. Calcuate the value of ```$45,000 in 1973``` in 2021 dollars to 2 decimal places with thousands separators.
#
# Print a statement that says "An executive's salary of **whatever_amount** in 1973 is equal to **updated_variable_here** in 2021."
#
# #### Formula for calcuating change in value (US Dollar):
# The updated salary is equal to old salary divided by old cpi and then times the current cpi value.
#
# - In this case the 1973 CPI value is 44.4.
# - The 2021 CPI value is 270.97.
#
# Again, do this programmatically by creating varibles and doing calculations. **Do not** just use cells as a calculator.

# %%
### answer question 2 here (create more cells if necessary)

salary_1973 = 45_000
cpi_1973 = 44.4
cpi_2021 = 270.97

salary_2021 = (salary_1973/cpi_1973) * cpi_2021

print(f"An executive's salary of ${salary_1973:,} in 1973 is equal to ${salary_2021:,.2F} in 2021.")
# Out:
# An executive's salary of $45,000 in 1973 is equal to $274,631.76 in 2021.

# %% [markdown]
# ## Working with Lists

# %% [markdown]
# ### Question 3
#
# You've <a href="https://apps.health.ny.gov/pubdoh/professionals/doctors/conduct/factions/AllRecordsAction.action?">scraped thousands of documents</a> that contain disciplinary actions against doctors in New York state. You compile key words and phrases that will target certain types of violations. These include:
#
# - improper touching
# - self-medication
# - self-prescribing
# - opioid addiction
# - harassment
# - coercion
# - sexual harrassment
# - sex
# - sexual favor
# - abuse of trust
# - opioid prescriptions in return for sex
#
# Create a list that holds the search terms above.

# %%
### answer question 3 here (create more cells if necessary)
search_terms = ["improper touching", "self-medication",
                "self-prescribing", "opioid addiction",
                "harassment", "coercion","sexual harrassment",
               "sex", "sexual favor", "abuse of trust",
               "opioid prescriptions in return for sex"]

search_terms
# Out:
# ['improper touching',
#  'self-medication',
#  'self-prescribing',
#  'opioid addiction',
#  'harassment',
#  'coercion',
#  'sexual harrassment',
#  'sex',
#  'sexual favor',
#  'abuse of trust',
#  'opioid prescriptions in return for sex']

# %% [markdown]
# ### Question 4
#
# Confirm that you have a list.

# %%
### answer question 4 here (create more cells if necessary)
type(search_terms)
# Out:
# list

# %% [markdown]
# ### Question 5
#
# How long is this list?

# %%
### answer question 5 here (create more cells if necessary)
len(search_terms)
# Out:
# 11

# %% [markdown]
# ## Working with List of Dictionaries

# %% [markdown]
# ### Question 6
#
# #### Create a list of dictionaries called "donations" using the content from the image below:
#
# ![donors.png](data:image/png;base64,...)
#
#
# You may copy and paste the content from this <a href="https://github.com/sandeepmj/practical_python_exercises/blob/master/support_files/giving.xlsx?raw=true" target="blank">Excel file</a>, but you must manually build the dictionaries.

# %%
### answer question 6 here (create more cells if necessary)
### NOT COVERED

# %% [markdown]
# ### Question 7
#
# How many dictionaries are in this list?
# Don't just manually count them.
# There will come a time when you will have thousands of items!

# %%
### answer question 7 here (create more cells if necessary)
### NOT COVERED

# %% [markdown]
# ## Congratulations!
#
# You just harnessed the power of Python to accomplish the following tasks that are critical foundational skills to become an advanced data journalist:
#
# 1. Making numbers more readable (using f-string literal formatting)
# 2. Organizing data points after acquiring them through scraping (creating lists, dictionaries and lists of dictionaries)
# 3. Knowing what type of data (or Python object) we have.
# 4. Knowing how many such data points we have.
